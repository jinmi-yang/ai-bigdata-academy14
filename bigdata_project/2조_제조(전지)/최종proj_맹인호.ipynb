# %%
import pandas as pd

# %%
bat_pc = pd.read_csv('./bat_process.csv',encoding='euc-KR')
judge = bat_pc.groupby('judge').size()
display(judge)
print('불량률:',(judge[0]/judge.sum()*100).round(3),'%')
# Out:
# /home/piai/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (97,101,102,103) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# judge
# 불량     1376
# 양품    42841
# dtype: int64
# 불량률: 3.112 %

# %%
pd.set_option('display.max_rows',None,'display.max_columns',None)
bat_pc.isna().sum()
# Out:
# lot_id                0
# tray_id               0
# dt_start              0
# cell_id               0
# judge                 0
# rta1_cell_no          0
# rta1_box_col          0
# rta1_box_row          0
# rta1_box_dan          0
# hta1_box_col          0
# hta1_box_row          0
# hta1_box_dan          0
# rta2_box_col          0
# rta2_box_row          0
# rta2_box_dan          0
# ocv1_ocv              0
# ocv1_box_col          0
# ocv1_box_dan          0
# c1_curr_end           0
# c1_voltage_avg        0
# c1_capa               0
# c1_ccval              0
# c1_time_cc            0
# c1_box_col            0
# c1_box_dan            0
# c1_temp_avg           0
# dc1_curr_end          0
# dc1_voltage_avg       0
# dc1_capa              0
# dc1_box_col           0
# dc1_box_dan           0
# dc1_temp_avg          0
# dc1_capafit           0
# c2_curr_end           0
# c2_voltage_avg        0
# c2_capa               0
# c2_ccval              0
# c2_time_cc            0
# ...

# %%
bat_pc[bat_pc['sa3_box_col'].isnull()]
# Out:
#         lot_id    tray_id                dt_start     cell_id judge  \
# 3527   LOT-103  TRAY-1148   09-02-2020 오후 1:43:20  CELL-13424    불량
# 8563   LOT-108  TRAY-1339   09-04-2020 오전 8:31:15  CELL-18539    불량
# 9544   LOT-109  TRAY-1379   09-04-2020 오후 5:15:05  CELL-19206    불량
# 9563   LOT-109  TRAY-1379   09-04-2020 오후 5:15:05  CELL-19745    불량
# 10781  LOT-108  TRAY-1429   09-05-2020 오전 4:24:45  CELL-18729    양품
# 10782  LOT-108  TRAY-1429   09-05-2020 오전 4:24:45  CELL-18730    양품
# 10784  LOT-108  TRAY-1429   09-05-2020 오전 4:24:45  CELL-18732    불량
# 10787  LOT-108  TRAY-1429   09-05-2020 오전 4:24:45  CELL-18735    불량
# 10790  LOT-108  TRAY-1429   09-05-2020 오전 4:24:45  CELL-18738    양품
# 10791  LOT-108  TRAY-1429   09-05-2020 오전 4:24:45  CELL-18739    불량
# 10792  LOT-108  TRAY-1429   09-05-2020 오전 4:24:45  CELL-18740    불량
# 10793  LOT-108  TRAY-1429   09-05-2020 오전 4:24:45  CELL-18741    양품
# 10794  LOT-108  TRAY-1429   09-05-2020 오전 4:24:45  CELL-18742    불량
# ...
